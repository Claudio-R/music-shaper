# %%
# !pip install flask_ngrok
# !pip install pyngrok
# !ngrok authtoken 2PpEEHueADZdBGdqVNyObhRn4IO_F2XDgqGoZHvVRsYAVBVf
#!pip install waitress
#!pip install serve-favicon
#!pip install express-favicon
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 681.2/681.2 kB 10.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyngrok: filename=pyngrok-6.0.0-py3-none-any.whl size=19867 sha256=aaf99931353aba3090f89acc49d47814a15cef699f2f48e0d5b22a7c47e63e4e
#   Stored in directory: /root/.cache/pip/wheels/5c/42/78/0c3d438d7f5730451a25f7ac6cbf4391759d22a67576ed7c2c
# Successfully built pyngrok
# ...
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
from google.colab import drive
drive.mount('/content/drive')
'''
# Remove Previous Videos
import os
import glob

files = glob.glob('/content/drive/MyDrive/AI/Video/*.mp4')
for f in files:
    os.remove(f)
    '''

# %%
from flask.templating import render_template
from flask import Flask, request, redirect, jsonify, send_file, session, redirect, url_for
import json, os, time, subprocess, pytz
from flask_ngrok import run_with_ngrok
from pyngrok import ngrok
#from datetime import datetime
#from waitress import serve


template_folder = '/content/drive/MyDrive/Scripts/template'
static_folder = '/content/drive/MyDrive/Scripts/static'

app = Flask(__name__, template_folder = template_folder, static_folder = static_folder)
run_with_ngrok(app)

@app.route("/")

@app.route('/home')
def home():
  return render_template('home.html')

@app.route('/process_array', methods=['POST'])
def process_array():
    data = request.get_json()  # ottieni i dati JSON dal corpo della richiesta
    array_data = data.get('arrayData')  # ottieni la stringa dal campo "stringData"
    print(array_data)
    response = {'message': 'Array_names ricevuto correttamente'}

    with open("/content/drive/MyDrive/names.txt", "w") as fo:
      for i in range(0, len(array_data)):
        print(array_data[i]),
        print(array_data[i])
        if i == 0:
          fo.write(array_data[i] + "&")
        else:
          fo.write(array_data[i])
    return jsonify(response)


@app.route('/process_array_choices', methods=['POST'])
def process_array_choices():
    data_choices = request.get_json()  # ottieni i dati JSON dal corpo della richiesta
    array_data_choices = data_choices.get('arrayDataChoices')  # ottieni la stringa dal campo "stringData"

    response = {'message': 'Array_choices ricevuto correttamente'}

    with open("/content/drive/MyDrive/style.txt", "w") as fo:
      for j in range(0, len(array_data_choices)):
        print(array_data_choices[j]),
        if j == 0 or j == 1:
          fo.write(array_data_choices[j] + "&")
        else:
          fo.write(array_data_choices[j])
    return jsonify(response)


@app.route('/execute_script', methods=['POST'])
def execute_script():
        # %run '/content/drive/MyDrive/ColabNotebooks/Copy_of_GenerateLyricsBasedVideo_clean_silvia.ipynb'



@app.route('/video')
def get_video():
    print("sono entrato in get_video")
    # Percorso del video nel server
    video_path = '/content/drive/MyDrive/AI/Video/Test.mp4'

    while not os.path.exists(video_path):
        # Attendi 1 secondo prima di riprovare
        time.sleep(10)


    # Invia il video al client
    return send_file(video_path, mimetype='video/mp4')


#app.run()
if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
#  * Running on http://f04b-35-230-17-155.ngrok-free.app
#  * Traffic stats available on http://127.0.0.1:4040
# INFO:werkzeug:127.0.0.1 - - [16/Jun/2023 13:09:51] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jun/2023 13:09:51] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jun/2023 13:09:57] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jun/2023 13:09:58] "GET /static/gui_logo.jpg HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jun/2023 13:09:58] "GET /static/style.css HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jun/2023 13:09:58] "GET /static/script.js HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Jun/2023 13:09:58] "GET /static/jsmenu.js HTTP/1.1" 200 -
# ...
